# %% [markdown]
# # Exploratory Data Analysis

# %%
import pandas as pd

# %%
#csv=comma seperated value file ,csv file is written in notepad and open in excel
market_analysis=pd.read_csv('marketing_analysis.csv',header=2)
market_analysis
# Out:
#        customerid   age  salary  balance   marital                  jobedu  \
# 0               1  58.0  100000     2143   married     management,tertiary
# 1               2  44.0   60000       29    single    technician,secondary
# 2               3  33.0  120000        2   married  entrepreneur,secondary
# 3               4  47.0   20000     1506   married     blue-collar,unknown
# 4               5  33.0       0        1    single         unknown,unknown
# ...           ...   ...     ...      ...       ...                     ...
# 45206       45207  51.0   60000      825   married     technician,tertiary
# 45207       45208  71.0   55000     1729  divorced         retired,primary
# 45208       45209  72.0   55000     5715   married       retired,secondary
# 45209       45210  57.0   20000      668   married   blue-collar,secondary
# 45210       45211  37.0  120000     2971   married  entrepreneur,secondary
#
#       targeted default housing loan    contact  day      month  \
# ...

# %%
type(market_analysis)
# Out:
# pandas.core.frame.DataFrame

# %%
#displaying data
#head shows top 5 rows
market_analysis.head()
# Out:
#    customerid   age  salary  balance  marital                  jobedu  \
# 0           1  58.0  100000     2143  married     management,tertiary
# 1           2  44.0   60000       29   single    technician,secondary
# 2           3  33.0  120000        2  married  entrepreneur,secondary
# 3           4  47.0   20000     1506  married     blue-collar,unknown
# 4           5  33.0       0        1   single         unknown,unknown
#
#   targeted default housing loan  contact  day      month duration  campaign  \
# 0      yes      no     yes   no  unknown    5  may, 2017  261 sec         1
# 1      yes      no     yes   no  unknown    5  may, 2017  151 sec         1
# 2      yes      no     yes  yes  unknown    5  may, 2017   76 sec         1
# 3       no      no     yes   no  unknown    5  may, 2017   92 sec         1
# 4       no      no      no   no  unknown    5  may, 2017  198 sec         1
#
#    pdays  previous poutcome response
# 0     -1         0  unknown       no
# ...

# %%
market_analysis.head(2)
# Out:
#    customerid   age  salary  balance  marital                jobedu targeted  \
# 0           1  58.0  100000     2143  married   management,tertiary      yes
# 1           2  44.0   60000       29   single  technician,secondary      yes
#
#   default housing loan  contact  day      month duration  campaign  pdays  \
# 0      no     yes   no  unknown    5  may, 2017  261 sec         1     -1
# 1      no     yes   no  unknown    5  may, 2017  151 sec         1     -1
#
#    previous poutcome response
# 0         0  unknown       no
# 1         0  unknown       no

# %%
# -3 will delete last three rows from data 

market_analysis.head(-3)
# Out:
#        customerid   age  salary  balance   marital                  jobedu  \
# 0               1  58.0  100000     2143   married     management,tertiary
# 1               2  44.0   60000       29    single    technician,secondary
# 2               3  33.0  120000        2   married  entrepreneur,secondary
# 3               4  47.0   20000     1506   married     blue-collar,unknown
# 4               5  33.0       0        1    single         unknown,unknown
# ...           ...   ...     ...      ...       ...                     ...
# 45203       45204  23.0    4000      113    single        student,tertiary
# 45204       45205  73.0   55000     2850   married       retired,secondary
# 45205       45206  25.0   60000      505    single    technician,secondary
# 45206       45207  51.0   60000      825   married     technician,tertiary
# 45207       45208  71.0   55000     1729  divorced         retired,primary
#
#       targeted default housing loan   contact  day      month  \
# ...

# %%
#tail will show last 5 rows
market_analysis.tail()
# Out:
#        customerid   age  salary  balance   marital                  jobedu  \
# 45206       45207  51.0   60000      825   married     technician,tertiary
# 45207       45208  71.0   55000     1729  divorced         retired,primary
# 45208       45209  72.0   55000     5715   married       retired,secondary
# 45209       45210  57.0   20000      668   married   blue-collar,secondary
# 45210       45211  37.0  120000     2971   married  entrepreneur,secondary
#
#       targeted default housing loan    contact  day      month  \
# 45206      yes      no      no   no   cellular   17  nov, 2017
# 45207      yes      no      no   no   cellular   17  nov, 2017
# 45208      yes      no      no   no   cellular   17  nov, 2017
# 45209      yes      no      no   no  telephone   17  nov, 2017
# 45210      yes      no      no   no   cellular   17  nov, 2017
#
#                    duration  campaign  pdays  previous poutcome response
# ...

# %%
#we can also select how many last rows we want to see
market_analysis.tail(n=2)
# Out:
#        customerid   age  salary  balance  marital                  jobedu  \
# 45209       45210  57.0   20000      668  married   blue-collar,secondary
# 45210       45211  37.0  120000     2971  married  entrepreneur,secondary
#
#       targeted default housing loan    contact  day      month  \
# 45209      yes      no      no   no  telephone   17  nov, 2017
# 45210      yes      no      no   no   cellular   17  nov, 2017
#
#                    duration  campaign  pdays  previous poutcome response
# 45209  8.46666666666667 min         4     -1         0  unknown       no
# 45210  6.01666666666667 min         2    188        11    other       no

# %%
#by -3 it will delete first 3 rows from data 
market_analysis.tail(-3)
# Out:
#        customerid   age  salary  balance   marital                  jobedu  \
# 3               4  47.0   20000     1506   married     blue-collar,unknown
# 4               5  33.0       0        1    single         unknown,unknown
# 5               6  35.0  100000      231   married     management,tertiary
# 6               7  28.0  100000      447    single     management,tertiary
# 7               8  42.0  120000        2  divorced   entrepreneur,tertiary
# ...           ...   ...     ...      ...       ...                     ...
# 45206       45207  51.0   60000      825   married     technician,tertiary
# 45207       45208  71.0   55000     1729  divorced         retired,primary
# 45208       45209  72.0   55000     5715   married       retired,secondary
# 45209       45210  57.0   20000      668   married   blue-collar,secondary
# 45210       45211  37.0  120000     2971   married  entrepreneur,secondary
#
#       targeted default housing loan    contact  day      month  \
# ...

# %%
#displaying random rows
market_analysis.sample()
# Out:
#        customerid   age  salary  balance marital               jobedu  \
# 18947       18948  41.0  100000     4477  single  management,tertiary
#
#       targeted default housing loan   contact  day      month  duration  \
# 18947       no      no      no   no  cellular    4  aug, 2017  5.95 min
#
#        campaign  pdays  previous poutcome response
# 18947         2     -1         0  unknown       no

# %%
# it will display  many random rows also
market_analysis.sample(4)
# Out:
#        customerid   age  salary  balance   marital               jobedu  \
# 23072       23073  42.0  100000     1243  divorced  management,tertiary
# 14302       14303  51.0   16000       30   married    housemaid,primary
# 42429       42430  64.0   55000     1220   married    retired,secondary
# 36795       36796  56.0   20000      373   married  blue-collar,primary
#
#       targeted default housing loan   contact  day      month  \
# 23072       no      no      no   no  cellular   26  aug, 2017
# 14302      yes      no     yes   no  cellular   14  jul, 2017
# 42429      yes      no      no   no  cellular    7  dec, 2017
# 36795      yes      no     yes   no  cellular   12  may, 2017
#
#                    duration  campaign  pdays  previous poutcome response
# 23072  16.6666666666667 min         4     -1         0  unknown      yes
# 14302              5.55 min         2     -1         0  unknown       no
# 42429               2.3 min         1     -1         0  unknown       no
# ...

# %%
#shape will show how many rows and columns in data
market_analysis.shape
# Out:
# (45211, 19)

# %%
#to display only rows 
print("total rows in data",market_analysis.shape[0])
# Out:
# total rows in data 45211

# %%
#to display only columns
x=market_analysis.shape[1]
# f is string format 
print(f"total columns in data {x}")
# Out:
# total columns in data 19

# %%
#multiplication of row and column
market_analysis.size
# Out:
# 859009

# %%
#it will show data types of each column 
market_analysis.dtypes
# Out:
# customerid      int64
# age           float64
# salary          int64
# balance         int64
# marital        object
# jobedu         object
# targeted       object
# default        object
# housing        object
# loan           object
# contact        object
# day             int64
# month          object
# duration       object
# campaign        int64
# pdays           int64
# previous        int64
# poutcome       object
# response       object
# dtype: object

# %%
#to see only one column datatype
market_analysis.age.dtype
# Out:
# dtype('float64')

# %%
#2 method 
market_analysis['age'].dtype
#mdifference is that in indexing it will also take gap in words ex ['Age OF Student']
# Out:
# dtype('float64')

# %%
#information given like non null and data type of column
market_analysis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 19 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerid  45211 non-null  int64
#  1   age         45191 non-null  float64
#  2   salary      45211 non-null  int64
#  3   balance     45211 non-null  int64
#  4   marital     45211 non-null  object
#  5   jobedu      45211 non-null  object
#  6   targeted    45211 non-null  object
#  7   default     45211 non-null  object
#  8   housing     45211 non-null  object
#  9   loan        45211 non-null  object
#  10  contact     45211 non-null  object
#  11  day         45211 non-null  int64
#  12  month       45161 non-null  object
#  13  duration    45211 non-null  object
#  14  campaign    45211 non-null  int64
#  15  pdays       45211 non-null  int64
#  16  previous    45211 non-null  int64
#  17  poutcome    45211 non-null  object
#  18  response    45181 non-null  object
# ...

# %%
#describe shows statistics on numerical data 
market_analysis.describe()
# Out:
#          customerid           age         salary        balance           day  \
# count  45211.000000  45191.000000   45211.000000   45211.000000  45211.000000
# mean   22606.000000     40.935651   57006.171065    1362.272058     15.806419
# std    13051.435847     10.619198   32085.718415    3044.765829      8.322476
# min        1.000000     18.000000       0.000000   -8019.000000      1.000000
# 25%    11303.500000     33.000000   20000.000000      72.000000      8.000000
# 50%    22606.000000     39.000000   60000.000000     448.000000     16.000000
# 75%    33908.500000     48.000000   70000.000000    1428.000000     21.000000
# max    45211.000000     95.000000  120000.000000  102127.000000     31.000000
#
#            campaign         pdays      previous
# count  45211.000000  45211.000000  45211.000000
# mean       2.763841     40.197828      0.580323
# std        3.098021    100.128746      2.303441
# min        1.000000     -1.000000      0.000000
# ...

# %%
#shows column name 
market_analysis.columns
# Out:
# Index(['customerid', 'age', 'salary', 'balance', 'marital', 'jobedu',
#        'targeted', 'default', 'housing', 'loan', 'contact', 'day', 'month',
#        'duration', 'campaign', 'pdays', 'previous', 'poutcome', 'response'],
#       dtype='object')

# %%
#drop column
#inplace means permanent delete from data 
#axis means from row or column
market_analysis.drop('customerid',axis='columns',inplace=True)

# %%
market_analysis.head(2)
# Out:
#     age  salary  balance  marital                jobedu targeted default  \
# 0  58.0  100000     2143  married   management,tertiary      yes      no
# 1  44.0   60000       29   single  technician,secondary      yes      no
#
#   housing loan  contact  day      month duration  campaign  pdays  previous  \
# 0     yes   no  unknown    5  may, 2017  261 sec         1     -1         0
# 1     yes   no  unknown    5  may, 2017  151 sec         1     -1         0
#
#   poutcome response
# 0  unknown       no
# 1  unknown       no

# %%
#to show all value in data  
market_analysis.isnull().sum()
# Out:
# age         20
# salary       0
# balance      0
# marital      0
# jobedu       0
# targeted     0
# default      0
# housing      0
# loan         0
# contact      0
# day          0
# month       50
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# response    30
# dtype: int64
